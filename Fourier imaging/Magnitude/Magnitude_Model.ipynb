# %%
import sys
from pathlib import Path
# Get the repository root (2 levels up from current notebook)
repo_root = Path(__file__).parent.parent.parent if '__file__' in globals() else Path.cwd().parent.parent
sys.path.insert(0, str(repo_root))

# import necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, mean_absolute_error, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
import Template
# Definición de modulos
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling  import SMOTE, ADASYN
from sklearn.decomposition import PCA
from Model_Productor import CNNModelProductor

# Instantiate the Template class
Template = Template.Template()

# %%
model_producer = CNNModelProductor(
    days=0  # Train on Day 0 only
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cpu
#
# Loading data from days: [0]
# Loaded 174 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_0
# Healthy: 24, Unhealthy: 150
#
# Dataset splits:
#   Training: 126 samples
#   Validation: 14 samples
#   Testing: 34 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6440, Train Acc: 0.7460 | Val Loss: 0.6837, Val Acc: 0.7857
# Epoch [2/50] Train Loss: 0.6155, Train Acc: 0.8492 | Val Loss: 0.6701, Val Acc: 0.7857
# Epoch [3/50] Train Loss: 0.5753, Train Acc: 0.8571 | Val Loss: 0.6482, Val Acc: 0.7857
# Epoch [4/50] Train Loss: 0.5654, Train Acc: 0.8492 | Val Loss: 0.6287, Val Acc: 0.7857
# Epoch [5/50] Train Loss: 0.5352, Train Acc: 0.8571 | Val Loss: 0.6046, Val Acc: 0.7857
# Epoch [6/50] Train Loss: 0.4998, Train Acc: 0.8571 | Val Loss: 0.5834, Val Acc: 0.7857
#
# ...

# %%
model_producer = CNNModelProductor(
    days=1 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cpu
#
# Loading data from days: [1]
# Loaded 178 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_1
# Healthy: 25, Unhealthy: 153
#
# Dataset splits:
#   Training: 129 samples
#   Validation: 14 samples
#   Testing: 35 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6504, Train Acc: 0.7442 | Val Loss: 0.6815, Val Acc: 0.7857
# Epoch [2/50] Train Loss: 0.6122, Train Acc: 0.8605 | Val Loss: 0.6638, Val Acc: 0.7857
# Epoch [3/50] Train Loss: 0.5683, Train Acc: 0.8760 | Val Loss: 0.6443, Val Acc: 0.7857
# Epoch [4/50] Train Loss: 0.5503, Train Acc: 0.8760 | Val Loss: 0.6204, Val Acc: 0.7857
# Epoch [5/50] Train Loss: 0.5026, Train Acc: 0.8760 | Val Loss: 0.6012, Val Acc: 0.7857
# Epoch [6/50] Train Loss: 0.4794, Train Acc: 0.8760 | Val Loss: 0.5771, Val Acc: 0.7857
#
# ...

# %%
model_producer = CNNModelProductor(
    days=2
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cpu
#
# Loading data from days: [2]
# Loaded 172 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_2
# Healthy: 24, Unhealthy: 148
#
# Dataset splits:
#   Training: 125 samples
#   Validation: 13 samples
#   Testing: 34 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6432, Train Acc: 0.7280 | Val Loss: 0.6782, Val Acc: 0.9231
# Epoch [2/50] Train Loss: 0.6094, Train Acc: 0.8800 | Val Loss: 0.6552, Val Acc: 0.9231
# Epoch [3/50] Train Loss: 0.5790, Train Acc: 0.8880 | Val Loss: 0.6202, Val Acc: 0.9231
# Epoch [4/50] Train Loss: 0.5421, Train Acc: 0.8880 | Val Loss: 0.5827, Val Acc: 0.9231
# Epoch [5/50] Train Loss: 0.5061, Train Acc: 0.8880 | Val Loss: 0.5404, Val Acc: 0.9231
# Epoch [6/50] Train Loss: 0.4687, Train Acc: 0.8880 | Val Loss: 0.4977, Val Acc: 0.9231
#
# ...

# %%
model_producer = CNNModelProductor(
    days=3 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cpu
#
# Loading data from days: [3]
# Loaded 178 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_3
# Healthy: 25, Unhealthy: 153
#
# Dataset splits:
#   Training: 129 samples
#   Validation: 14 samples
#   Testing: 35 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6524, Train Acc: 0.7209 | Val Loss: 0.6819, Val Acc: 0.7857
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 model_producer = CNNModelProductor(
#       2     days=3
#       3 )
# ----> 5 results = model_producer.run_full_pipeline(save_dir=None)
#       7 model_producer.plot_confusion_matrix(results=results)
#
# ...

# %%
model_producer = CNNModelProductor(
    days=4 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=5 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=6
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=7
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=8 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=9
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=10
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=11 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=12
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=13
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=14
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=15
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
