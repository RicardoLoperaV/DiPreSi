# %%
import sys
from pathlib import Path
# Get the repository root (2 levels up from current notebook)
repo_root = Path(__file__).parent.parent.parent if '__file__' in globals() else Path.cwd().parent.parent
sys.path.insert(0, str(repo_root))

# import necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, mean_absolute_error, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
import Template
# Definición de modulos
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling  import SMOTE, ADASYN
from sklearn.decomposition import PCA
from Model_Productor import CNNModelProductor

# Instantiate the Template class
Template = Template.Template()

# %%
model_producer = CNNModelProductor(
    days=0 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [0]
# Loaded 352 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_0
# Healthy: 176, Unhealthy: 176
#
# Dataset splits:
#   Training: 254 samples
#   Validation: 28 samples
#   Testing: 70 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6967, Train Acc: 0.5236 | Val Loss: 0.6917, Val Acc: 0.5714
# Epoch [2/50] Train Loss: 0.6970, Train Acc: 0.4724 | Val Loss: 0.6935, Val Acc: 0.4286
# Epoch [3/50] Train Loss: 0.6958, Train Acc: 0.5433 | Val Loss: 0.6946, Val Acc: 0.4286
# Epoch [4/50] Train Loss: 0.6966, Train Acc: 0.4921 | Val Loss: 0.6952, Val Acc: 0.4286
# Epoch [5/50] Train Loss: 0.6967, Train Acc: 0.4843 | Val Loss: 0.6956, Val Acc: 0.4286
# Epoch [6/50] Train Loss: 0.6921, Train Acc: 0.5354 | Val Loss: 0.6969, Val Acc: 0.4286
# Epoch [7/50] Train Loss: 0.6959, Train Acc: 0.5079 | Val Loss: 0.6951, Val Acc: 0.4286
# Epoch [8/50] Train Loss: 0.6908, Train Acc: 0.5276 | Val Loss: 0.6960, Val Acc: 0.4286
# Epoch [9/50] Train Loss: 0.6883, Train Acc: 0.5551 | Val Loss: 0.6967, Val Acc: 0.4286
# Epoch [10/50] Train Loss: 0.6953, Train Acc: 0.5276 | Val Loss: 0.6988, Val Acc: 0.4286
# Epoch [11/50] Train Loss: 0.6882, Train Acc: 0.5472 | Val Loss: 0.6972, Val Acc: 0.4286
# Epoch [12/50] Train Loss: 0.6883, Train Acc: 0.5591 | Val Loss: 0.6968, Val Acc: 0.4286
# Epoch [13/50] Train Loss: 0.6881, Train Acc: 0.5276 | Val Loss: 0.6974, Val Acc: 0.4286
# Epoch [14/50] Train Loss: 0.6965, Train Acc: 0.4961 | Val Loss: 0.6972, Val Acc: 0.4286
# Epoch [15/50] Train Loss: 0.6901, Train Acc: 0.5000 | Val Loss: 0.6966, Val Acc: 0.4286
# Epoch [16/50] Train Loss: 0.6870, Train Acc: 0.4961 | Val Loss: 0.6986, Val Acc: 0.4286
# Epoch [17/50] Train Loss: 0.6869, Train Acc: 0.5236 | Val Loss: 0.6999, Val Acc: 0.4286
# Epoch [18/50] Train Loss: 0.6900, Train Acc: 0.5551 | Val Loss: 0.6985, Val Acc: 0.4286
# Epoch [19/50] Train Loss: 0.6929, Train Acc: 0.5118 | Val Loss: 0.6981, Val Acc: 0.4286
# Epoch [20/50] Train Loss: 0.6972, Train Acc: 0.4921 | Val Loss: 0.6963, Val Acc: 0.4286
# Epoch [21/50] Train Loss: 0.6875, Train Acc: 0.5591 | Val Loss: 0.6936, Val Acc: 0.4286
# Epoch [22/50] Train Loss: 0.6845, Train Acc: 0.5669 | Val Loss: 0.6970, Val Acc: 0.4286
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.5571
# Balanced Accuracy: 0.5000
# Precision: 0.3104
# Recall: 0.5571
# F1-Score: 0.3987
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.56      1.00      0.72        39
#      Healthy       0.00      0.00      0.00        31
#
#     accuracy                           0.56        70
#    macro avg       0.28      0.50      0.36        70
# weighted avg       0.31      0.56      0.40        70
#
#
# Confusion Matrix:
# [[39  0]
#  [31  0]]

# %%
model_producer = CNNModelProductor(
    days=1 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [1]
# Loaded 358 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_1
# Healthy: 179, Unhealthy: 179
#
# Dataset splits:
#   Training: 259 samples
#   Validation: 28 samples
#   Testing: 71 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6960, Train Acc: 0.4981 | Val Loss: 0.6952, Val Acc: 0.4286
# Epoch [2/50] Train Loss: 0.6953, Train Acc: 0.4981 | Val Loss: 0.6956, Val Acc: 0.4286
# Epoch [3/50] Train Loss: 0.6942, Train Acc: 0.5753 | Val Loss: 0.6944, Val Acc: 0.4286
# Epoch [4/50] Train Loss: 0.6880, Train Acc: 0.5328 | Val Loss: 0.6952, Val Acc: 0.4286
# Epoch [5/50] Train Loss: 0.6936, Train Acc: 0.4942 | Val Loss: 0.6978, Val Acc: 0.4286
# Epoch [6/50] Train Loss: 0.6906, Train Acc: 0.5097 | Val Loss: 0.6993, Val Acc: 0.4286
#
# Early stopping at epoch 6 due to no improvement in validation accuracy for 5 consecutive epochs.
#
# Training completed. Best validation accuracy: 0.4286
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.4648
# Balanced Accuracy: 0.5000
# Precision: 0.2160
# Recall: 0.4648
# F1-Score: 0.2950
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.46      1.00      0.63        33
#      Healthy       0.00      0.00      0.00        38
#
#     accuracy                           0.46        71
#    macro avg       0.23      0.50      0.32        71
# weighted avg       0.22      0.46      0.29        71
#
#
# Confusion Matrix:
# [[33  0]
#  [38  0]]

# %%
model_producer = CNNModelProductor(
    days=2
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [2]
# Loaded 350 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_2
# Healthy: 175, Unhealthy: 175
#
# Dataset splits:
#   Training: 252 samples
#   Validation: 28 samples
#   Testing: 70 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.7018, Train Acc: 0.4206 | Val Loss: 0.6921, Val Acc: 0.5357
# Epoch [2/50] Train Loss: 0.6905, Train Acc: 0.5238 | Val Loss: 0.6914, Val Acc: 0.5357
# Epoch [3/50] Train Loss: 0.6914, Train Acc: 0.5119 | Val Loss: 0.6906, Val Acc: 0.5357
# Epoch [4/50] Train Loss: 0.6950, Train Acc: 0.4881 | Val Loss: 0.6893, Val Acc: 0.5357
# Epoch [5/50] Train Loss: 0.6948, Train Acc: 0.5040 | Val Loss: 0.6883, Val Acc: 0.5357
# Epoch [6/50] Train Loss: 0.6901, Train Acc: 0.5595 | Val Loss: 0.6878, Val Acc: 0.5357
#
# Early stopping at epoch 6 due to no improvement in validation accuracy for 5 consecutive epochs.
#
# Training completed. Best validation accuracy: 0.5357
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.4714
# Balanced Accuracy: 0.5000
# Precision: 0.2222
# Recall: 0.4714
# F1-Score: 0.3021
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.47      1.00      0.64        33
#      Healthy       0.00      0.00      0.00        37
#
#     accuracy                           0.47        70
#    macro avg       0.24      0.50      0.32        70
# weighted avg       0.22      0.47      0.30        70
#
#
# Confusion Matrix:
# [[33  0]
#  [37  0]]

# %%
model_producer = CNNModelProductor(
    days=3 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [3]
# Loaded 358 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_3
# Healthy: 179, Unhealthy: 179
#
# Dataset splits:
#   Training: 259 samples
#   Validation: 28 samples
#   Testing: 71 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6963, Train Acc: 0.4903 | Val Loss: 0.6955, Val Acc: 0.4286
# Epoch [2/50] Train Loss: 0.6956, Train Acc: 0.4942 | Val Loss: 0.6981, Val Acc: 0.4286
# Epoch [3/50] Train Loss: 0.6948, Train Acc: 0.5637 | Val Loss: 0.6984, Val Acc: 0.4286
# Epoch [4/50] Train Loss: 0.6888, Train Acc: 0.5483 | Val Loss: 0.6984, Val Acc: 0.4286
# Epoch [5/50] Train Loss: 0.6941, Train Acc: 0.5019 | Val Loss: 0.6984, Val Acc: 0.4286
# Epoch [6/50] Train Loss: 0.6912, Train Acc: 0.5135 | Val Loss: 0.6979, Val Acc: 0.4286
#
# Early stopping at epoch 6 due to no improvement in validation accuracy for 5 consecutive epochs.
#
# Training completed. Best validation accuracy: 0.4286
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.4648
# Balanced Accuracy: 0.5000
# Precision: 0.2160
# Recall: 0.4648
# F1-Score: 0.2950
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.46      1.00      0.63        33
#      Healthy       0.00      0.00      0.00        38
#
#     accuracy                           0.46        71
#    macro avg       0.23      0.50      0.32        71
# weighted avg       0.22      0.46      0.29        71
#
#
# Confusion Matrix:
# [[33  0]
#  [38  0]]

# %%
model_producer = CNNModelProductor(
    days=4 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [4]
# Loaded 356 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_4
# Healthy: 178, Unhealthy: 178
#
# Dataset splits:
#   Training: 257 samples
#   Validation: 28 samples
#   Testing: 71 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6933, Train Acc: 0.5175 | Val Loss: 0.6951, Val Acc: 0.4643
# Epoch [2/50] Train Loss: 0.6922, Train Acc: 0.5019 | Val Loss: 0.6959, Val Acc: 0.4643
# Epoch [3/50] Train Loss: 0.6873, Train Acc: 0.5681 | Val Loss: 0.6963, Val Acc: 0.4643
# Epoch [4/50] Train Loss: 0.6971, Train Acc: 0.4903 | Val Loss: 0.6965, Val Acc: 0.4643
# Epoch [5/50] Train Loss: 0.6898, Train Acc: 0.5292 | Val Loss: 0.6954, Val Acc: 0.4643
# Epoch [6/50] Train Loss: 0.6957, Train Acc: 0.5331 | Val Loss: 0.6960, Val Acc: 0.4643
#
# Early stopping at epoch 6 due to no improvement in validation accuracy for 5 consecutive epochs.
#
# Training completed. Best validation accuracy: 0.4643
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.4648
# Balanced Accuracy: 0.5000
# Precision: 0.2160
# Recall: 0.4648
# F1-Score: 0.2950
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.46      1.00      0.63        33
#      Healthy       0.00      0.00      0.00        38
#
#     accuracy                           0.46        71
#    macro avg       0.23      0.50      0.32        71
# weighted avg       0.22      0.46      0.29        71
#
#
# Confusion Matrix:
# [[33  0]
#  [38  0]]

# %%
model_producer = CNNModelProductor(
    days=5 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [5]
# Loaded 356 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_5
# Healthy: 178, Unhealthy: 178
#
# Dataset splits:
#   Training: 257 samples
#   Validation: 28 samples
#   Testing: 71 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6927, Train Acc: 0.5136 | Val Loss: 0.6953, Val Acc: 0.4643
# Epoch [2/50] Train Loss: 0.6916, Train Acc: 0.5214 | Val Loss: 0.6968, Val Acc: 0.4643
# Epoch [3/50] Train Loss: 0.6875, Train Acc: 0.5603 | Val Loss: 0.6978, Val Acc: 0.4643
# Epoch [4/50] Train Loss: 0.6969, Train Acc: 0.4864 | Val Loss: 0.6975, Val Acc: 0.4643
# Epoch [5/50] Train Loss: 0.6898, Train Acc: 0.5331 | Val Loss: 0.6952, Val Acc: 0.4643
# Epoch [6/50] Train Loss: 0.6967, Train Acc: 0.5253 | Val Loss: 0.6958, Val Acc: 0.4643
#
# Early stopping at epoch 6 due to no improvement in validation accuracy for 5 consecutive epochs.
#
# Training completed. Best validation accuracy: 0.4643
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.4648
# Balanced Accuracy: 0.5000
# Precision: 0.2160
# Recall: 0.4648
# F1-Score: 0.2950
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.46      1.00      0.63        33
#      Healthy       0.00      0.00      0.00        38
#
#     accuracy                           0.46        71
#    macro avg       0.23      0.50      0.32        71
# weighted avg       0.22      0.46      0.29        71
#
#
# Confusion Matrix:
# [[33  0]
#  [38  0]]

# %%
model_producer = CNNModelProductor(
    days=6
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [6]
# Loaded 350 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_6
# Healthy: 175, Unhealthy: 175
#
# Dataset splits:
#   Training: 252 samples
#   Validation: 28 samples
#   Testing: 70 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.7017, Train Acc: 0.4167 | Val Loss: 0.6920, Val Acc: 0.5357
# Epoch [2/50] Train Loss: 0.6920, Train Acc: 0.5119 | Val Loss: 0.6915, Val Acc: 0.5357
# Epoch [3/50] Train Loss: 0.6921, Train Acc: 0.5159 | Val Loss: 0.6917, Val Acc: 0.5357
# Epoch [4/50] Train Loss: 0.6967, Train Acc: 0.4762 | Val Loss: 0.6913, Val Acc: 0.5357
# Epoch [5/50] Train Loss: 0.6941, Train Acc: 0.5040 | Val Loss: 0.6906, Val Acc: 0.5357
# Epoch [6/50] Train Loss: 0.6911, Train Acc: 0.5595 | Val Loss: 0.6904, Val Acc: 0.5357
#
# Early stopping at epoch 6 due to no improvement in validation accuracy for 5 consecutive epochs.
#
# Training completed. Best validation accuracy: 0.5357
#
# Evaluating model on test set...
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\ricar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.4714
# Balanced Accuracy: 0.5000
# Precision: 0.2222
# Recall: 0.4714
# F1-Score: 0.3021
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       0.47      1.00      0.64        33
#      Healthy       0.00      0.00      0.00        37
#
#     accuracy                           0.47        70
#    macro avg       0.24      0.50      0.32        70
# weighted avg       0.22      0.47      0.30        70
#
#
# Confusion Matrix:
# [[33  0]
#  [37  0]]

# %%
model_producer = CNNModelProductor(
    days=7
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# GPU Memory: 8.00 GB
#
# Loading data from days: [7]
# Loaded 312 samples from c:\Users\ricar\Documents\GitHub\DiPreSi\Fourier imaging\Magnitude\Fourier_Images\Day_7
# Healthy: 156, Unhealthy: 156
#
# Dataset splits:
#   Training: 225 samples
#   Validation: 25 samples
#   Testing: 62 samples
#
# Building CNN model...
# Total parameters: 106,306
# Trainable parameters: 106,306
#
# Starting training...
# Epoch [1/50] Train Loss: 0.6937, Train Acc: 0.5378 | Val Loss: 0.6924, Val Acc: 0.5200
# Epoch [2/50] Train Loss: 0.6891, Train Acc: 0.5333 | Val Loss: 0.6922, Val Acc: 0.5200
# Epoch [3/50] Train Loss: 0.6834, Train Acc: 0.5511 | Val Loss: 0.6920, Val Acc: 0.4800
# Epoch [31/50] Train Loss: 0.5675, Train Acc: 0.7467 | Val Loss: 0.6078, Val Acc: 0.5600
# Epoch [32/50] Train Loss: 0.5329, Train Acc: 0.8089 | Val Loss: 1.0743, Val Acc: 0.4800
# Epoch [33/50] Train Loss: 0.5293, Train Acc: 0.8000 | Val Loss: 0.9560, Val Acc: 0.4800
# Epoch [34/50] Train Loss: 0.5134, Train Acc: 0.8222 | Val Loss: 0.6114, Val Acc: 0.5600
# Epoch [35/50] Train Loss: 0.4892, Train Acc: 0.8311 | Val Loss: 0.8925, Val Acc: 0.4800
# Epoch [36/50] Train Loss: 0.5347, Train Acc: 0.7422 | Val Loss: 0.9088, Val Acc: 0.4800
# Epoch [37/50] Train Loss: 0.5362, Train Acc: 0.7600 | Val Loss: 0.5929, Val Acc: 0.5600
# Epoch [38/50] Train Loss: 0.5052, Train Acc: 0.8000 | Val Loss: 0.6341, Val Acc: 0.5600
# Epoch [39/50] Train Loss: 0.5187, Train Acc: 0.7956 | Val Loss: 0.5442, Val Acc: 0.6000
# Epoch [40/50] Train Loss: 0.4759, Train Acc: 0.8044 | Val Loss: 0.8352, Val Acc: 0.5200
# Epoch [41/50] Train Loss: 0.4921, Train Acc: 0.8311 | Val Loss: 1.0340, Val Acc: 0.4800
# Epoch [42/50] Train Loss: 0.4549, Train Acc: 0.8533 | Val Loss: 1.1333, Val Acc: 0.4800
# Epoch [43/50] Train Loss: 0.4330, Train Acc: 0.8489 | Val Loss: 1.3584, Val Acc: 0.4800
# Epoch [44/50] Train Loss: 0.4305, Train Acc: 0.8356 | Val Loss: 1.1800, Val Acc: 0.4800
# Epoch [45/50] Train Loss: 0.4579, Train Acc: 0.8133 | Val Loss: 0.6225, Val Acc: 0.5600
# Epoch [46/50] Train Loss: 0.4184, Train Acc: 0.8711 | Val Loss: 0.8676, Val Acc: 0.5200
# Epoch [47/50] Train Loss: 0.4316, Train Acc: 0.8267 | Val Loss: 0.7200, Val Acc: 0.5200
# Epoch [48/50] Train Loss: 0.4314, Train Acc: 0.8444 | Val Loss: 0.8277, Val Acc: 0.5200
# Epoch [49/50] Train Loss: 0.4141, Train Acc: 0.8356 | Val Loss: 0.4689, Val Acc: 0.6400
# Epoch [50/50] Train Loss: 0.3819, Train Acc: 0.8667 | Val Loss: 0.3862, Val Acc: 0.8000
#
# Training completed. Best validation accuracy: 0.9600
#
# Evaluating model on test set...
#
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.9194
# Balanced Accuracy: 0.9138
# Precision: 0.9300
# Recall: 0.9194
# F1-Score: 0.9184
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Unhealthy       1.00      0.83      0.91        29
#      Healthy       0.87      1.00      0.93        33
#
#     accuracy                           0.92        62
#    macro avg       0.93      0.91      0.92        62
# weighted avg       0.93      0.92      0.92        62
#
#
# Confusion Matrix:
# [[24  5]
#  [ 0 33]]

# %%
model_producer = CNNModelProductor(
    days=8 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=9
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=10
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=11 
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=12
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=13
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=14
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)

# %%
model_producer = CNNModelProductor(
    days=15
)

results = model_producer.run_full_pipeline(save_dir=None)

model_producer.plot_confusion_matrix(results=results)
